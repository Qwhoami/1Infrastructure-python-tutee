# %% [markdown]
# # if

# %%
# if
# indentation 주의

gate = True
if gate:
  print('yes')
else:
  print('no')

# %%
# 비교 연산자
# < , >, == , !=, >=, <=
if 1> 2:
  print('no')
else:
  print('yes')

# %%
# or and not

a = [1,2,3]
b = [3,4,5]

if 2 in a and 2 in b:
  print('good')
else:
  print('bad')


if 2 not in a:
  print('yes')
else:
  print('no')

# %%
# if문에는 조건이 들어가야함 안들어가기 원하면 pass
a = [1,2,3]
b = [3,4,5]

if 2 in a and 2 in b:
  print('good')
else:
  pass
print('end of if statements')

# %%
eda = ['cello','viola', 'spice']
if 'cello' not in eda:
  pass
else:
  if not 'tcad':
    print('tcad')
  else:
    print('viola')

# %%
eda = ['cello','viola', 'spice']
if 'cello' not in eda:
  pass
elif 'tacd' in eda:
  print('tcad')


else:
  print('viola')

# %%
eda = ['cello','viola', 'spice']
if 'cello' not in eda: pass
else: print('viola')

# %%
a = 10
if a >= 5 :
  print('yes')
else:
  print('no')

 # 참일때 조건 if 조건식 else 거짓일때
print('yes') if a >=10 else print('no')

# %% [markdown]
# # 반복문

# %%
# while True
# 조건을 만족할때 까지만 실행
a = 0
while a < 5:
  a += 1
  print(a)

print('End',a)


# VScode Debugging:

# %%
a=0
while True:
  a += 1
  print(a)
  if a ==10:
    break


print('End',a)

# %%
a=0
while a < 10:
  a += 1
  if a < 5:
    continue # while 로 다시 돌아감
  print(a)


print('End',a)

# %%
a=0
while a < 10:
  a += 1
  if a < 5:
    pass #그냥 지나감
  print(a)


print('End',a)

# %%
a=0
b=[]
while True:
  a+=1
  b.append(a)
  if len(b) == 5:
    b.clear()
  print(b)

# %% [markdown]
# # For loop

# %%
# for 변수 in iterable variable (list, tupel, ,,,):
a = [2,2,3]
for test in a:
  print(test)
# Out:
# 2
# 2
# 3

# %%
a = [(1,2), (2,3), (3,4)]

for (b, c) in a:
  print(b, c)

print('')

for b, c in a:
  print(b, c)
# Out:
# 1 2
# 2 3
# 3 4
#
# 1 2
# 2 3
# 3 4

# %%
for i in range(1, 11): # range(start, stop, step) --> start ~ stop-1
  print(i, end=' in loop\n')

print('')

for i in range(1, 11, 2):
  print(i)
# Out:
# 1 in loop
# 2 in loop
# 3 in loop
# 4 in loop
# 5 in loop
# 6 in loop
# 7 in loop
# 8 in loop
# 9 in loop
# 10 in loop
#
# 1
# 3
# 5
# 7
# 9

# %%
# out=[]
# for num in [1,2,3]:
#   out.append(num)
# print(out) # --> [1, 2, 3]

out = [    num for num in [1,2,3]      ]
print(out)

print('')

# out=[]
# for num in [1,2,3]:
#   if num % 2 != 0:
#     out.append(num)
# print(out) # --> [1, 3]

out = [    num for num in [1,2,3] if num % 2 != 0  ]
print(out)
# Out:
# [1, 2, 3]
#
# [1, 3]
