# %% [markdown]
# # Python tutorial plan

# %%
'''

1. Materials
  https://docs.python.org/3/tutorial/index.html

2. Lecture (After every Monday weekly meeting)

  # Basic (4weeks, 251013~251107)

      Python introduction

      Google Colab

      1. Varialbe and Data type

      2. Control statement

      3. Input and Output

      4. Class and Modules

3. Git
  tutorial에서 진행한 내용 업로드 --> https://github.com/Qwhoami/1Infrastructure-python-tutee

'''

# %% [markdown]
# # Python introduction

# %%
'''
History
  1991 python 최초 발표
    - Guido Van Rossum
  2000 python2
  2008 python3


단점
  속도 느림: https://www.youtube.com/watch?v=7gnCc2L3558 (125배 느림, 하나 명령어 실행시에는 20~50배 정도 차)

장점
  쉬움
    - user friendly
    - 다른 언어에 비해 직관적

  써먹을곳 많음, 확장성, 개발 속도 빠
    - 웹프로그래밍
    - 인공지능
    - 수치연산 프로그래밍
    - 데이터 관리 및 분

  사람들 많이 사용: 의견 공유 가능
    - https://www.tiobe.com/tiobe-index/
    - https://pypl.github.io/PYPL.html#google_vignette

  상대적으로 느린 python (interpreter) 대비 빠른 C언어(complier)와 조합가능
    - numpy: libary mostly written in C

'''

# %% [markdown]
# # Google Colab

# %%
'''
  Google colab: 구글이 제공하는 클라우드 기반 text editor 환경
    1. Google login
    2. google에서 google colab 검색
    3. + New notebook
    *Keyboar shortcut: Ctrl + M H
'''

# %%
print ('hello world')
# Out:
# hello world

# %%
import platform

print(   platform.platform()    )

print('\ncolab platform detatils')
# !cat /etc/issue.net

print('\ncolab cpu info')
# !cat /proc/cpuinfo

print('\ncolab memory info')
# !cat /proc/meminfo

print('\npython version')
# !python --version
# Out:
# Linux-6.6.105+-x86_64-with-glibc2.35
#
# colab platform detatils
# Ubuntu 22.04.4 LTS
#
# colab cpu info
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# ...

# %%
print('hello world')
