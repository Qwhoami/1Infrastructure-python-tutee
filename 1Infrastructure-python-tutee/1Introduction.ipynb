# %% [markdown]
# # Python tutorial plan
# 교육해보면서 계획 수정 예정

# %%
'''

Materials
  https://docs.python.org/3/tutorial/index.html
  https://github.com/Qwhoami

Lecture

  # Basic (6weeks, 251013~251122)

      Python introduction

      Google Colab

      1. Data type (자료형)
        - 숫자형, 문자열, 리스트, 튜플, 딕셔너리, 집합, 불자료형, 변수

      2. 제어문
        - If, while, for

      3. 입출력
        - 함수, print, 파일 읽고쓰기

      4. 클래스 및 모듈
        - 클래스, 모듈, 패키지, 예외처리, 내장함수, 외부 라이브러리

      5. 이터레이션, 제너레이터
        - 클로저, 데코레이터, 이터레이션, 제너레이터

      6. 정규표현식

  # Intermediate (260101~)
    효율적인 파이썬 코딩, 프로파일링

'''

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python introduction

# %%
'''
History
  1991 python 최초 발표
    - Guido Van Rossum
  2000 python2
  2008 python3


단점
  속도 느림: https://www.youtube.com/watch?v=7gnCc2L3558 (125배 느림, 하나 명령어 실행시에는 20~50배 정도 차)
  Reason1:
    # 컴파일된 Assembly C와 달리 interpreter 방식으로 실행하려면 코드를 한줄한줄 실행
  Reason2:
    #C: Primitive type, 메모리에 값을 그대로 저장
    #Python: Reference type, 해당 값을 저장한 메모리의 위치를 저장

장점
  쉬움
    - user friendly
    - 다른 언어에 비해 직관적

  써먹을곳 많음, 확장성, 개발 속도 빠
    - 웹프로그래밍
    - 인공지능
    - 수치연산 프로그래밍
    - 데이터 관리 및 분

  사람들 많이 사용: 의견 공유 가능
    - https://www.tiobe.com/tiobe-index/
    - https://pypl.github.io/PYPL.html#google_vignette

  상대적으로 느린 python (interpreter) 대비 빠른 C언어(complier)와 조합가능
    - numpy: libary mostly written in C

'''

# %% [markdown]
# # Google Colab

# %%
'''
  Google colab: 구글이 제공하는 클라우드 기반 text editor 환경
  Google login
  Keyboar shortcut: Ctrl + M H
'''

# %%
import platform

print(platform.platform())

print('\ncolab platform detatils')
# !cat /etc/issue.net

print('\ncolab cpu info')
# !cat /proc/cpuinfo

print('\ncolab memory info')
# !cat /proc/meminfo

print('\npython version')
# !python --version

# %%
print('hello world')
