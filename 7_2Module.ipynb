# %%
'''
mod.py
'''
def test():
    print('this is test1')

#print('this is called automatically')
# module로써 재사용성 안좋음 --> 뒤에서 다시 설명: 특정 함수만 호출 하고 싶은데 같이 실행됨
# 다른 파일에서 import 시에는 기본적으로 아무것도 동작하지 않는게 좋음
# module 생성시 함수 형태로 작성하는것이 좋음

print(__name__) #__main__, __name__은 특별한 내장변수로 파이썬 파일의 현재 상태를 나타냄

#외부에서 호출시 자동으로 실행되는것을 방지
#mod.py 자체에서 실행시 __name__ => __name__
#main.py에서 호출시 __name__ ==> mod

# 코드 실행 분리 위함
# 아래 코드는 외부에서 사용시 호출 안됨
if __name__ == "__main__":
    test()


'''
tests.py
'''
# 개발은 혼자 하지 않음
# 각자 함수를 개발하고 호출하는 형태로 사용되었음
import mod
# print(__name__) --> mod
mod.test() # 함수만 호하고 싶지만

# import test.mod # 상대경로

# import ..mod # 뒤로는 안됨

# import sys
# sys.path.append('/home/kjr/Desktop')
# import mod

# from mod import test
# test()
